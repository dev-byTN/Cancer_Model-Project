# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# /home/tristan/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
dt = pd.read_csv("dataset.csv")
dt
# Out:
#      Unnamed: 0        Age  Menopause  Taille_tumeur  Ganglions_touches  \
# 0             1        NaN        1.0            NaN                NaN
# 1             2  51.240996        2.0      16.874618                1.0
# 2             3        NaN        2.0            NaN                NaN
# 3             4        NaN        1.0      25.608588                NaN
# 4             5  55.254881        2.0      43.438748                2.0
# ..          ...        ...        ...            ...                ...
# 297        2651  52.048990        2.0      33.089490               11.0
# 298         308  75.745550        2.0      15.239369                9.0
# 299         347  54.688155        2.0      23.642077                2.0
# 300         378  57.920124        2.0      22.087332                2.0
# 301         385  51.870528        2.0      20.393468                1.0
#
#      Metastases  Grade  Lateralite  Quadrant Irradiation  Recidive
# 0           2.0    3.0         NaN       3.0           1       NaN
# 1           1.0    1.0         2.0       1.0           1       1.0
# 2           1.0    NaN         NaN       2.0           1       NaN
# 3           NaN    2.0         NaN       NaN         NaN       1.0
# 4           1.0    3.0         1.0       3.0           1       1.0
# ..          ...    ...         ...       ...         ...       ...
# 297         NaN    3.0         1.0       2.0           2       1.0
# 298         NaN    1.0         1.0       2.0           2       2.0
# 299         NaN    1.0         1.0       2.0           1       2.0
# 300         NaN    1.0         1.0       3.0           1       2.0
# 301         NaN    1.0         1.0       3.0           1       2.0
#
# [302 rows x 11 columns]

# %%
dt = dt.drop("Unnamed: 0", axis="columns", inplace=False)

# %%
dt.dtypes
# Out:
# Age                  float64
# Menopause            float64
# Taille_tumeur        float64
# Ganglions_touches    float64
# Metastases           float64
# Grade                float64
# Lateralite           float64
# Quadrant             float64
# Irradiation           object
# Recidive             float64
# dtype: object

# %%
dt.isnull().sum()
# Out:
# Age                  110
# Menopause             40
# Taille_tumeur        106
# Ganglions_touches     81
# Metastases            76
# Grade                 78
# Lateralite            57
# Quadrant              87
# Irradiation           65
# Recidive             136
# dtype: int64

# %%
dt
# Out:
#            Age  Menopause  Taille_tumeur  Ganglions_touches  Metastases  \
# 0          NaN        1.0            NaN                NaN         2.0
# 1    51.240996        2.0      16.874618                1.0         1.0
# 2          NaN        2.0            NaN                NaN         1.0
# 3          NaN        1.0      25.608588                NaN         NaN
# 4    55.254881        2.0      43.438748                2.0         1.0
# ..         ...        ...            ...                ...         ...
# 297  52.048990        2.0      33.089490               11.0         NaN
# 298  75.745550        2.0      15.239369                9.0         NaN
# 299  54.688155        2.0      23.642077                2.0         NaN
# 300  57.920124        2.0      22.087332                2.0         NaN
# 301  51.870528        2.0      20.393468                1.0         NaN
#
#      Grade  Lateralite  Quadrant Irradiation  Recidive
# 0      3.0         NaN       3.0           1       NaN
# 1      1.0         2.0       1.0           1       1.0
# 2      NaN         NaN       2.0           1       NaN
# 3      2.0         NaN       NaN         NaN       1.0
# 4      3.0         1.0       3.0           1       1.0
# ..     ...         ...       ...         ...       ...
# 297    3.0         1.0       2.0           2       1.0
# 298    1.0         1.0       2.0           2       2.0
# 299    1.0         1.0       2.0           1       2.0
# 300    1.0         1.0       3.0           1       2.0
# 301    1.0         1.0       3.0           1       2.0
#
# [302 rows x 10 columns]

# %% [markdown]
# <h4>To see if there's no relevant Age data</h4>

# %%
sns.boxplot(data = dt["Age"])
plt.ylim(0, 100)
plt.title("Répartition des valeurs liées à l'âge")
plt.show()

# %%
dt["Age"].describe()
# Out:
# count    192.000000
# mean      53.059182
# std       26.269277
# min       27.269382
# 25%       43.416635
# 50%       52.367426
# 75%       58.709683
# max      378.787350
# Name: Age, dtype: float64

# %% [markdown]
# <h4>To see if there's more than 3 values for the menopause and 4 for the grade</h4>

# %%
dt["Menopause"].value_counts()
# Out:
# Menopause
# 1.0    135
# 2.0    127
# Name: count, dtype: int64

# %%
#We good fot the menopause variable

# %%
dt.Grade.value_counts()
# Out:
# Grade
# 2.0     97
# 3.0     72
# 1.0     54
# 34.0     1
# Name: count, dtype: int64

# %%
#We only have 1 record with the observation 34. We can suppose that the doctor type 34 by mistake. The one wanted was probably 3

# %% [markdown]
# <h5>No the correlation between the age and the menopause</h5>

# %%
plt.scatter(dt["Age"], dt["Menopause"], color="red")
plt.title("Patient ménopausé ou pas en fonction de son âge")
plt.show()

# %%
#The values of age are very close so the scatter plot doesn't give much information. We can't see clearly if there's a pattern

# %% [markdown]
# <h4>Tumor size density</h4>

# %%
rounded = dt
#rounded["Taille_tumeur"] = round(rounded["Taille_tumeur"], 0)

# %%
rounded["Taille_tumeur"].plot.density(bw_method='scott', color='blue', linestyle='-', linewidth=2)
plt.title("Densité des observations concernant la taille de la tumeur")
# Out:
# Text(0.5, 1.0, 'Densité des observations concernant la taille de la tumeur')

# %%
rounded["Taille_tumeur"].describe()
# Out:
# count    196.000000
# mean      26.127106
# std       10.389460
# min        1.714647
# 25%       18.812693
# 50%       26.549199
# 75%       32.257666
# max       53.422745
# Name: Taille_tumeur, dtype: float64

# %%
#Un graphique Q-Q (Quantile-Quantile) est utilisé pour vérifier si un ensemble de données suit une distribution théorique particulière.
#QQPlot on tumor size + Shapiro test to see if it rejects null hypotesis ( pvalue > 0.5 )

# %%
import statsmodels.api as sm
import pylab as py

sm.qqplot(rounded["Taille_tumeur"], line = '45')
py.title("QQplot sur la taille de la tumeur")
py.show()

# %%
from scipy.stats import shapiro

shapiroo = shapiro(rounded["Taille_tumeur"])
shapiroo
# Out:
# ShapiroResult(statistic=np.float64(nan), pvalue=np.float64(nan))

# %%
#It doesn't work with Null Values
rounded = rounded.dropna(subset=["Taille_tumeur"])
rounded
# Out:
#            Age  Menopause  Taille_tumeur  Ganglions_touches  Metastases  \
# 1    51.240996        2.0      16.874618                1.0         1.0
# 3          NaN        1.0      25.608588                NaN         NaN
# 4    55.254881        2.0      43.438748                2.0         1.0
# 5    46.298965        1.0      10.601184                2.0         1.0
# 9    56.972747        2.0      30.606762                0.0         NaN
# ..         ...        ...            ...                ...         ...
# 297  52.048990        2.0      33.089490               11.0         NaN
# 298  75.745550        2.0      15.239369                9.0         NaN
# 299  54.688155        2.0      23.642077                2.0         NaN
# 300  57.920124        2.0      22.087332                2.0         NaN
# 301  51.870528        2.0      20.393468                1.0         NaN
#
#      Grade  Lateralite  Quadrant Irradiation  Recidive
# 1      1.0         2.0       1.0           1       1.0
# 3      2.0         NaN       NaN         NaN       1.0
# 4      3.0         1.0       3.0           1       1.0
# 5      2.0         1.0       3.0           1       1.0
# 9      NaN         2.0       NaN           1       NaN
# ..     ...         ...       ...         ...       ...
# 297    3.0         1.0       2.0           2       1.0
# 298    1.0         1.0       2.0           2       2.0
# 299    1.0         1.0       2.0           1       2.0
# 300    1.0         1.0       3.0           1       2.0
# 301    1.0         1.0       3.0           1       2.0
#
# [196 rows x 10 columns]

# %%
shapiroo = shapiro(rounded["Taille_tumeur"])
shapiroo
# Out:
# ShapiroResult(statistic=np.float64(0.9834111157624116), pvalue=np.float64(0.0205546977172848))

# %%
#P_value < 0.05 so we reject null hypothesis. Like the QQPlot shows us, the tumor size is not following the normal law

# %% [markdown]
# <h3>Ganglions touchés</h3>

# %%
import seaborn as sns

# %%
sns.histplot(dt["Ganglions_touches"], kde=True)
plt.title("Distribution de la variable Ganglions touchés")
plt.show()

# %%
dt[dt["Ganglions_touches"] <= 0] 
#Nous pouvons voir qu'un patient possède une valeur négative
# Out:
#            Age  Menopause  Taille_tumeur  Ganglions_touches  Metastases  \
# 6    45.554682        NaN            NaN                0.0         1.0
# 9    56.972747        2.0      30.606762                0.0         NaN
# 13   68.220159        NaN            NaN                0.0         1.0
# 25         NaN        2.0      28.122551                0.0         1.0
# 41   76.576234        2.0      40.209071                0.0         1.0
# 47         NaN        2.0      20.139057                0.0         1.0
# 48   55.136335        2.0      16.734485                0.0         1.0
# 53   53.165019        2.0      10.893529                0.0         1.0
# 54   44.961764        1.0      25.793588                0.0         1.0
# 58   43.452982        1.0      25.090640                0.0         1.0
# 60   33.243909        1.0       1.801674                0.0         1.0
# 61   56.595160        2.0      36.622342                0.0         1.0
# 68   45.424820        1.0      36.378141                0.0         1.0
# 70   65.251394        2.0      22.062777                0.0         1.0
# 76   65.114903        2.0      31.212433               -1.0         1.0
# 81         NaN        NaN            NaN                0.0         NaN
# 86         NaN        2.0      33.194668                0.0         1.0
# 89   27.269382        1.0      36.445383                0.0         1.0
# 100  41.790623        1.0      43.484116                0.0         1.0
# 103  63.926919        2.0      10.623472                0.0         1.0
# 110  50.494103        1.0      31.777624                0.0         1.0
# 115  40.322327        1.0      50.427394                0.0         1.0
# 116  54.094026        2.0      21.744990                0.0         1.0
# 123  42.389547        1.0      22.461566                0.0         1.0
# 124        NaN        NaN            NaN                0.0         NaN
# 141  68.658483        2.0      33.280132                0.0         1.0
# 143  55.947117        2.0      25.827509                0.0         1.0
# 144  58.576210        1.0      32.780172                0.0         NaN
# 148  45.823894        1.0      40.859673                0.0         1.0
# 151  45.072693        1.0      22.944516                0.0         1.0
# 152  54.224589        1.0      27.008217                0.0         1.0
# 153  53.294863        NaN            NaN                0.0         1.0
# 158  62.718334        2.0      28.858419                0.0         1.0
# 172        NaN        1.0      11.393224                0.0         1.0
# 174  52.749805        1.0      27.485544                0.0         1.0
# 177  41.604054        1.0      31.370192                0.0         1.0
# 181  68.200018        2.0      25.999838                0.0         1.0
# 184  73.727927        2.0      23.094500                0.0         1.0
# 190  61.136603        2.0      31.739495                0.0         1.0
# 191  68.027749        2.0      23.428167                0.0         1.0
# 198        NaN        NaN            NaN                0.0         NaN
# 215        NaN        NaN            NaN                0.0         NaN
# 219  47.966657        1.0      20.694028                0.0         1.0
# 228  44.656080        NaN            NaN                0.0         1.0
# 243  56.188332        1.0      26.116248                0.0         1.0
# 248  64.620274        2.0      33.674438                0.0         NaN
# 264  67.573383        2.0      20.017179                0.0         1.0
# 269  55.449271        1.0      27.775989                0.0         1.0
# 270  54.493005        1.0      31.082550                0.0         1.0
# 276        NaN        NaN            NaN                0.0         NaN
# 279  37.901895        1.0       3.394642                0.0         1.0
# 288        NaN        NaN            NaN                0.0         NaN
#
#      Grade  Lateralite  Quadrant Irradiation  Recidive
# 6      2.0         2.0       NaN         NaN       NaN
# 9      NaN         2.0       NaN           1       NaN
# 13     2.0         2.0       NaN         NaN       NaN
# 25     NaN         1.0       5.0         NaN       NaN
# 41     NaN         2.0       NaN         NaN       1.0
# 47     NaN         2.0       3.0         NaN       NaN
# 48     1.0         2.0       1.0           1       1.0
# 53     1.0         1.0       2.0           1       1.0
# 54     2.0         2.0       1.0           1       1.0
# 58     2.0         2.0       2.0           1       1.0
# 60     2.0         2.0       1.0           1       1.0
# 61     3.0         1.0       3.0           1       1.0
# 68     1.0         2.0       3.0           1       2.0
# 70     2.0         1.0       3.0           1       1.0
# 76     2.0         1.0       2.0           2       1.0
# 81     1.0         1.0       3.0           1       NaN
# 86     NaN         2.0       2.0         NaN       NaN
# 89     2.0         2.0       5.0           1       1.0
# 100    2.0         2.0       2.0           1       1.0
# 103    2.0         1.0       2.0           1       1.0
# 110    3.0         1.0       2.0           1       1.0
# 115    2.0         1.0       2.0           1       1.0
# 116    2.0         2.0       1.0           1       2.0
# 123    1.0         2.0       5.0           1       1.0
# 124    2.0         2.0       5.0           1       NaN
# 141    3.0         1.0       2.0           1       1.0
# 143    2.0         1.0       2.0           1       1.0
# 144    NaN         2.0       NaN           2       NaN
# 148    1.0         1.0       2.0           1       2.0
# 151    2.0         2.0       3.0           1       1.0
# 152    2.0         1.0       2.0           1       1.0
# 153    1.0         1.0       NaN         NaN       NaN
# 158    NaN         2.0       NaN         NaN       1.0
# 172    NaN         1.0       2.0         NaN       NaN
# 174    1.0         1.0       2.0           1       1.0
# 177    1.0         1.0       5.0           1       1.0
# 181    3.0         1.0       4.0           2       2.0
# 184    3.0         1.0       3.0           1       1.0
# 190    1.0         1.0       3.0           1       1.0
# 191    1.0         1.0       2.0           1       1.0
# 198    2.0         2.0       5.0           1       NaN
# 215    2.0         1.0       2.0           2       NaN
# 219    2.0         1.0       2.0           1       2.0
# 228    1.0         1.0       NaN         NaN       NaN
# 243    NaN         2.0       NaN         NaN       2.0
# 248    NaN         2.0       NaN           2       NaN
# 264    NaN         2.0       NaN         NaN       2.0
# 269    1.0         2.0       3.0           1       2.0
# 270    3.0         1.0       5.0           1       2.0
# 276    1.0         2.0       3.0           1       NaN
# 279    2.0         2.0       1.0           1       2.0
# 288    3.0         2.0       2.0           2       NaN

# %%
#Comme nous avons des valeurs <= 0, nous ne pouvons pas faire BoxCox ( log(x) et log(0) existe pas )
#Nous faisons donc Yeo-Johnson

# %% [markdown]
# <h4>Metastases</h4>

# %%
dt["Metastases"].value_counts() 
# 1 = Metastase visible
# 2 = Metastase non visible
# Autre = Valeur aberrante
# Out:
# Metastases
# 1.0    178
# 2.0     48
# Name: count, dtype: int64

# %% [markdown]
# <h4>Grade</h4>

# %%
sns.histplot(dt["Grade"], kde=True)
plt.title("Distribution du grade chez le patient")
plt.show()

# %%
#We can see a dot near the 35.
#So we look in detail
dt['Grade'].value_counts()
# Out:
# Grade
# 2.0     97
# 3.0     72
# 1.0     54
# 34.0     1
# Name: count, dtype: int64

# %% [markdown]
# <h4>Lateralité</h4>

# %%
#Valeur possible : 1 & 2
# 1 -> cancer sein gauche
# 2 -> cancr sein droit
#Autre -> Ano

dt["Lateralite"].value_counts()
# Out:
# Lateralite
# 1.0    131
# 2.0    114
# Name: count, dtype: int64

# %% [markdown]
# <h4>Quadrant</h4>

# %%
sns.histplot(dt["Quadrant"], kde=True)
plt.title("Répartition des zones du sein touché.")
plt.show()

# %% [markdown]
# <h4>Irradiation</h4>

# %%
#We think if tumor size < 5 cm & ganglions touché = 0 --> no irradiation ( cause small )
#First of all let's check if irraidtion != 1 or != 2

dt[dt["Irradiation"] > 2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 4
#       1 #We think if tumor size < 5 cm & ganglions touché = 0 --> no irradiation ( cause small )
#       2 #First of all let's check if irraidtion != 1 or != 2
# ----> 4 dt[dt["Irradiation"] > 2]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# File ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'
