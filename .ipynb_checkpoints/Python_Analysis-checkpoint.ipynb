# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# /home/tristan/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
dt = pd.read_csv("dataset.csv")
dt
# Out:
#      Unnamed: 0        Age  Menopause  Taille_tumeur  Ganglions_touches  \
# 0             1        NaN        1.0            NaN                NaN
# 1             2  51.240996        2.0      16.874618                1.0
# 2             3        NaN        2.0            NaN                NaN
# 3             4        NaN        1.0      25.608588                NaN
# 4             5  55.254881        2.0      43.438748                2.0
# ..          ...        ...        ...            ...                ...
# 297        2651  52.048990        2.0      33.089490               11.0
# 298         308  75.745550        2.0      15.239369                9.0
# 299         347  54.688155        2.0      23.642077                2.0
# 300         378  57.920124        2.0      22.087332                2.0
# 301         385  51.870528        2.0      20.393468                1.0
#
#      Metastases  Grade  Lateralite  Quadrant Irradiation  Recidive
# 0           2.0    3.0         NaN       3.0           1       NaN
# 1           1.0    1.0         2.0       1.0           1       1.0
# 2           1.0    NaN         NaN       2.0           1       NaN
# 3           NaN    2.0         NaN       NaN         NaN       1.0
# 4           1.0    3.0         1.0       3.0           1       1.0
# ..          ...    ...         ...       ...         ...       ...
# 297         NaN    3.0         1.0       2.0           2       1.0
# 298         NaN    1.0         1.0       2.0           2       2.0
# 299         NaN    1.0         1.0       2.0           1       2.0
# 300         NaN    1.0         1.0       3.0           1       2.0
# 301         NaN    1.0         1.0       3.0           1       2.0
#
# [302 rows x 11 columns]

# %%
dt = dt.drop("Unnamed: 0", axis="columns", inplace=False)

# %%
dt.dtypes
# Out:
# Age                  float64
# Menopause            float64
# Taille_tumeur        float64
# Ganglions_touches    float64
# Metastases           float64
# Grade                float64
# Lateralite           float64
# Quadrant             float64
# Irradiation           object
# Recidive             float64
# dtype: object

# %%
dt.isnull().sum()
# Out:
# Age                  110
# Menopause             40
# Taille_tumeur        106
# Ganglions_touches     81
# Metastases            76
# Grade                 78
# Lateralite            57
# Quadrant              87
# Irradiation           65
# Recidive             136
# dtype: int64

# %%
dt
# Out:
#            Age  Menopause  Taille_tumeur  Ganglions_touches  Metastases  \
# 0          NaN        1.0            NaN                NaN         2.0
# 1    51.240996        2.0      16.874618                1.0         1.0
# 2          NaN        2.0            NaN                NaN         1.0
# 3          NaN        1.0      25.608588                NaN         NaN
# 4    55.254881        2.0      43.438748                2.0         1.0
# ..         ...        ...            ...                ...         ...
# 297  52.048990        2.0      33.089490               11.0         NaN
# 298  75.745550        2.0      15.239369                9.0         NaN
# 299  54.688155        2.0      23.642077                2.0         NaN
# 300  57.920124        2.0      22.087332                2.0         NaN
# 301  51.870528        2.0      20.393468                1.0         NaN
#
#      Grade  Lateralite  Quadrant Irradiation  Recidive
# 0      3.0         NaN       3.0           1       NaN
# 1      1.0         2.0       1.0           1       1.0
# 2      NaN         NaN       2.0           1       NaN
# 3      2.0         NaN       NaN         NaN       1.0
# 4      3.0         1.0       3.0           1       1.0
# ..     ...         ...       ...         ...       ...
# 297    3.0         1.0       2.0           2       1.0
# 298    1.0         1.0       2.0           2       2.0
# 299    1.0         1.0       2.0           1       2.0
# 300    1.0         1.0       3.0           1       2.0
# 301    1.0         1.0       3.0           1       2.0
#
# [302 rows x 10 columns]

# %% [markdown]
# <h4>To see if there's no relevant Age data</h4>

# %%
dt["Age"].plot.density(bw_method='scott', color='blue', linestyle='-', linewidth=2)
plt.title("Densité des observations concernant l'âge du patient")
# Out:
# Text(0.5, 1.0, "Densité des observations concernant l'âge du patient")

# %%
dt["Age"].describe()
# Out:
# count    192.000000
# mean      53.059182
# std       26.269277
# min       27.269382
# 25%       43.416635
# 50%       52.367426
# 75%       58.709683
# max      378.787350
# Name: Age, dtype: float64

# %% [markdown]
# <h4>To see if there's more than 2 values for the menopause and 3 for the grade</h4>

# %%
dt["Menopause"].value_counts()
# Out:
# Menopause
# 1.0    135
# 2.0    127
# Name: count, dtype: int64

# %%
#We good fot the menopause variable

# %%
dt.Grade.value_counts()
# Out:
# Grade
# 2.0     97
# 3.0     72
# 1.0     54
# 34.0     1
# Name: count, dtype: int64

# %%
#We only have 1 record with the observation 34. We can suppose that the doctor type 34 by mistake. The one wanted was probably 3

# %% [markdown]
# <h5>No the correlation between the age and the menopause</h5>

# %%
plt.scatter(dt["Age"], dt["Menopause"], color="red")
plt.title("Patient ménopausé ou pas en fonction de son âge")
plt.xlabel("Age")
plt.ylabel("Menopausé ?")
plt.xlim(20, 80)
plt.show()

# %%
#The values of age are very close so the scatter plot doesn't give much information. We can't see clearly if there's a pattern

# %% [markdown]
# <h4>Tumor size density</h4>

# %%
sns.boxplot(data = dt["Taille_tumeur"])
#plt.ylim(50, 55)
plt.title("Répartition des obsersavtions liées à la taille de la tumeur")
plt.show()

# %%
dt["Taille_tumeur"].describe()
# Out:
# count    196.000000
# mean      26.127106
# std       10.389460
# min        1.714647
# 25%       18.812693
# 50%       26.549199
# 75%       32.257666
# max       53.422745
# Name: Taille_tumeur, dtype: float64

# %%
#Un graphique Q-Q (Quantile-Quantile) est utilisé pour vérifier si un ensemble de données suit une distribution théorique particulière.
#QQPlot on tumor size + Shapiro test to see if it rejects null hypotesis ( pvalue > 0.5 )

# %%
import statsmodels.api as sm
import pylab as py

sm.qqplot(dt["Taille_tumeur"], line = '45')
py.title("QQplot sur la taille de la tumeur")
py.show()

# %%
from scipy.stats import shapiro

rounded = dt
shapiroo = shapiro(rounded["Taille_tumeur"])
shapiroo
# Out:
# ShapiroResult(statistic=np.float64(nan), pvalue=np.float64(nan))

# %%
#It doesn't work with Null Values
rounded = rounded.dropna(subset=["Taille_tumeur"])
rounded
# Out:
#            Age  Menopause  Taille_tumeur  Ganglions_touches  Metastases  \
# 1    51.240996        2.0      16.874618                1.0         1.0
# 3          NaN        1.0      25.608588                NaN         NaN
# 4    55.254881        2.0      43.438748                2.0         1.0
# 5    46.298965        1.0      10.601184                2.0         1.0
# 9    56.972747        2.0      30.606762                0.0         NaN
# ..         ...        ...            ...                ...         ...
# 297  52.048990        2.0      33.089490               11.0         NaN
# 298  75.745550        2.0      15.239369                9.0         NaN
# 299  54.688155        2.0      23.642077                2.0         NaN
# 300  57.920124        2.0      22.087332                2.0         NaN
# 301  51.870528        2.0      20.393468                1.0         NaN
#
#      Grade  Lateralite  Quadrant Irradiation  Recidive
# 1      1.0         2.0       1.0           1       1.0
# 3      2.0         NaN       NaN         NaN       1.0
# 4      3.0         1.0       3.0           1       1.0
# 5      2.0         1.0       3.0           1       1.0
# 9      NaN         2.0       NaN           1       NaN
# ..     ...         ...       ...         ...       ...
# 297    3.0         1.0       2.0           2       1.0
# 298    1.0         1.0       2.0           2       2.0
# 299    1.0         1.0       2.0           1       2.0
# 300    1.0         1.0       3.0           1       2.0
# 301    1.0         1.0       3.0           1       2.0
#
# [196 rows x 10 columns]

# %%
shapiroo = shapiro(rounded["Taille_tumeur"])
shapiroo
# Out:
# ShapiroResult(statistic=np.float64(0.9834111157624116), pvalue=np.float64(0.0205546977172848))

# %%
#P_value < 0.05 so we reject null hypothesis. Like the QQPlot shows us, the tumor size is not following the normal law

# %%
plt.scatter(dt["Taille_tumeur"], dt["Ganglions_touches"])
plt.xlim(52,55)
plt.xlabel("Taille de la tumeur")
plt.ylabel("Nombre de ganglions touchés")
plt.show()

# %% [markdown]
# <h3>Test de Grubs pour savoir mathématiquement s'il y a des valeurs aberrantes pour la taille de la tumeur</h3>

# %% [markdown]
# <h3>Ganglions touchés</h3>

# %%
import seaborn as sns

# %%
sns.boxplot(data = dt["Ganglions_touches"])
# Out:
# <Axes: ylabel='Ganglions_touches'>

# %%
sns.histplot(dt["Ganglions_touches"], kde=True)
plt.title("Distribution de la variable Ganglions touchés")
plt.show()

# %%
dt[dt["Ganglions_touches"] < 0].head()
#Nous pouvons voir qu'un patient possède une valeur négative
# Out:
#           Age  Menopause  Taille_tumeur  Ganglions_touches  Metastases  Grade  \
# 76  65.114903        2.0      31.212433               -1.0         1.0    2.0
#
#     Lateralite  Quadrant Irradiation  Recidive
# 76         1.0       2.0           2       1.0

# %%
#Comme nous avons des valeurs <= 0, nous ne pouvons pas faire BoxCox ( log(x) et log(0) existe pas )
#Nous faisons donc Yeo-Johnson

# %%
#De plus, avoir plus de 10 ganglions touché pour un patient est rare.
#Mais pas imposible.Pour savoir si notre observation est aberrantes, nous allons la comparer avec la taille de la tumeur. 
#Si beaucoup de ganglions touchés mais une taille de tumeur petite, nous pouvons conclure que c'est une erreur.

# %%
big_ganglions = dt[dt["Ganglions_touches"] > 9]
plt.scatter(dt["Taille_tumeur"], dt["Ganglions_touches"])
plt.ylabel("Ganglions_touchés")
plt.xlabel("Taille de la tumeur")
plt.show()

# %%
#Aucun lien, aucun cluster, les variables sont indépendantes

# %% [markdown]
# <h4>Metastases</h4>

# %%
dt["Metastases"].value_counts() 
# 1 = Metastase visible
# 2 = Metastase non visible
# Autre = Valeur aberrante
# Out:
# Metastases
# 1.0    178
# 2.0     48
# Name: count, dtype: int64

# %% [markdown]
# <h4>Grade</h4>

# %%
sns.histplot(dt["Grade"], kde=True, color="red")
plt.title("Distribution du grade chez le patient")
plt.show()

# %%
#We can see a dot near the 35.
#So we look in detail
dt['Grade'].value_counts()
# Out:
# Grade
# 2.0     97
# 3.0     72
# 1.0     54
# 34.0     1
# Name: count, dtype: int64

# %% [markdown]
# <h4>Lateralité</h4>

# %%
#Valeur possible : 1 & 2
# 1 -> cancer sein gauche
# 2 -> cancr sein droit
#Autre -> Ano

dt["Lateralite"].value_counts()
# Out:
# Lateralite
# 1.0    131
# 2.0    114
# Name: count, dtype: int64

# %% [markdown]
# <h4>Quadrant</h4>

# %%
sns.histplot(dt["Quadrant"], kde=True)
plt.title("Répartition des zones du sein touché.")
plt.show()

# %% [markdown]
# <h4>Irradiation</h4>

# %%
dt["Irradiation"] = pd.to_numeric(dt["Irradiation"], errors='coerce')

# %%
#We think if tumor size < 5 cm & ganglions touché = 0 --> no irradiation ( cause small )
#First of all let's check if irraidtion != 1 or != 2

dt.Irradiation.value_counts()
# Out:
# Irradiation
# 1.0    177
# 2.0     59
# Name: count, dtype: int64

# %% [markdown]
# <h4>Recidive</h4>

# %%
dt.Recidive.value_counts()
# Out:
# Recidive
# 1.0    101
# 2.0     65
# Name: count, dtype: int64

# %%
#Recap valeurs aberantes:
#Age -> 1 observation ; 378
#Grade -> 1 observation : 34
#Ganglion_touche -> 1 observation : -1

# %% [markdown]
# <h4>Traitement données aberrantes</h4>

# %% [markdown]
# <h5>Age</h5>

# %%
dt[dt["Age"] > 350]# On suppose que le patient à 37,78735 car non ménopausé.
# Out:
#            Age  Menopause  Taille_tumeur  Ganglions_touches  Metastases  \
# 139  378.78735        1.0        5.47359                2.0         1.0
#
#      Grade  Lateralite  Quadrant  Irradiation  Recidive
# 139    2.0         1.0       4.0          1.0       1.0

# %% [markdown]
# <h5>Nombre de ganglions</h5>

# %%
grade1 = dt[dt["Grade"] == 1]
grade2 = dt[dt["Grade"] == 2]
grade3 = dt[dt["Grade"] == 3]

# %%
dt[dt["Ganglions_touches"] == -1]
# Out:
#           Age  Menopause  Taille_tumeur  Ganglions_touches  Metastases  Grade  \
# 76  65.114903        2.0      31.212433               -1.0         1.0    2.0
#
#     Lateralite  Quadrant  Irradiation  Recidive
# 76         1.0       2.0          2.0       1.0

# %%
sns.histplot(grade2["Ganglions_touches"], kde=True)
plt.title("Nombre de ganglions touchés pour grade=2")
plt.xlim(-1, 10)
plt.show()

# %%
#We choose to change -1 to 1 cause majority of distribution.

# %% [markdown]
# <h5>Grade</h5>

# %%
dt[dt["Grade"] == 34]
# Out:
#            Age  Menopause  Taille_tumeur  Ganglions_touches  Metastases  \
# 232  57.542278        NaN            NaN                4.0         2.0
#
#      Grade  Lateralite  Quadrant  Irradiation  Recidive
# 232   34.0         2.0       NaN          NaN       NaN

# %%
recidive = dt[dt["Age"]<35]

plt.scatter(recidive["Age"], recidive["Grade"])
plt.xlim(20, 35)
plt.ylim(0,4)
plt.show()

# %%
recidive
# Out:
#            Age  Menopause  Taille_tumeur  Ganglions_touches  Metastases  \
# 28   32.230700        1.0      18.913529                2.0         1.0
# 34   34.665583        1.0      17.339789                1.0         1.0
# 49   31.573261        1.0      25.798925                2.0         1.0
# 51   30.223943        1.0      12.217858                2.0         1.0
# 60   33.243909        1.0       1.801674                0.0         1.0
# 89   27.269382        1.0      36.445383                0.0         1.0
# 102  32.424542        1.0      28.543095                5.0         2.0
# 165  34.715689        2.0      16.689622                2.0         1.0
# 189  31.609554        1.0            NaN                NaN         1.0
# 213  32.895294        1.0      18.499644                2.0         1.0
# 224  30.365161        1.0      22.086866                2.0         NaN
# 230  33.274215        1.0       1.714647                1.0         1.0
# 250  31.304141        NaN            NaN                5.0         1.0
# 253  33.407738        1.0      36.340054                2.0         1.0
# 260  31.681993        1.0      31.477418                5.0         1.0
# 262  34.184142        1.0            NaN                NaN         1.0
# 267  30.427485        NaN            NaN                8.0         2.0
# 272  32.701115        1.0            NaN                NaN         1.0
# 280  33.023036        1.0      32.725281                1.0         1.0
#
#      Grade  Lateralite  Quadrant  Irradiation  Recidive
# 28     1.0         1.0       2.0          1.0       1.0
# 34     1.0         1.0       2.0          1.0       1.0
# 49     2.0         2.0       2.0          1.0       1.0
# 51     1.0         2.0       2.0          1.0       1.0
# 60     2.0         2.0       1.0          1.0       1.0
# 89     2.0         2.0       5.0          1.0       1.0
# 102    3.0         1.0       2.0          2.0       2.0
# 165    3.0         2.0       3.0          1.0       1.0
# 189    NaN         1.0       NaN          1.0       NaN
# 213    1.0         2.0       2.0          1.0       2.0
# 224    NaN         1.0       NaN          2.0       NaN
# 230    2.0         2.0       1.0          1.0       2.0
# 250    3.0         2.0       NaN          NaN       NaN
# 253    3.0         1.0       2.0          1.0       2.0
# 260    3.0         2.0       3.0          2.0       2.0
# 262    NaN         2.0       NaN          2.0       NaN
# 267    3.0         1.0       NaN          NaN       NaN
# 272    NaN         2.0       NaN          1.0       NaN
# 280    1.0         2.0       3.0          1.0       2.0

# %% [markdown]
# <h3> Données manquantes</h3>

# %%
#Nous avons une distribution sans structure car aucune varibale de temporalité et les non-observations sont aléatoire.
#Rien ne nous permet de définir une structure et un schéma pour les valeurs manquantes.

# %%
#On va essayer de voir si MAR ( si une variable nulle va avoir une incidence sur une autre variable.

# %%
#Nous pensons que si taille_tumeur == null -> nbe ganglions_touches == null

# %%
mar_taille_tumeur = dt[dt["Taille_tumeur"].isnull()]
print(f"Nb de valeurs null pour la taille de la tumeur : {mar_taille_tumeur.Taille_tumeur.isnull().sum()}")
print(f"Nb de valeurs null pour le nombre de ganglions : {mar_taille_tumeur.Ganglions_touches.isnull().sum()}")
# Out:
# Nb de valeurs null pour la taille de la tumeur : 106
# Nb de valeurs null pour le nombre de ganglions : 66

# %%
mar_taille_tumeur
# Out:
#            Age  Menopause  Taille_tumeur  Ganglions_touches  Metastases  \
# 0          NaN        1.0            NaN                NaN         2.0
# 2          NaN        2.0            NaN                NaN         1.0
# 6    45.554682        NaN            NaN                0.0         1.0
# 7          NaN        NaN            NaN               17.0         NaN
# 8    65.124040        2.0            NaN                NaN         1.0
# ..         ...        ...            ...                ...         ...
# 281        NaN        2.0            NaN                NaN         1.0
# 284        NaN        NaN            NaN               11.0         NaN
# 285        NaN        1.0            NaN                NaN         1.0
# 286  58.131884        NaN            NaN                2.0         1.0
# 288        NaN        NaN            NaN                0.0         NaN
#
#      Grade  Lateralite  Quadrant  Irradiation  Recidive
# 0      3.0         NaN       3.0          1.0       NaN
# 2      NaN         NaN       2.0          1.0       NaN
# 6      2.0         2.0       NaN          NaN       NaN
# 7      2.0         2.0       3.0          2.0       NaN
# 8      NaN         2.0       NaN          1.0       NaN
# ..     ...         ...       ...          ...       ...
# 281    3.0         NaN       2.0          1.0       NaN
# 284    2.0         2.0       3.0          1.0       NaN
# 285    3.0         NaN       5.0          1.0       NaN
# 286    2.0         1.0       NaN          NaN       NaN
# 288    3.0         2.0       2.0          2.0       NaN
#
# [106 rows x 10 columns]

# %%
# So our case is MCAR
