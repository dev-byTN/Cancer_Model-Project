# %%
x <- 10
print(x)
# Out:
# [1] 10

# %%
dt <- readRDS(file="Train_dataset_incomplete.rds")

# %%
write.csv(dt, "dataset.csv", row.names=TRUE)

# %%
dt
# Out:
#      Age      Menopause Taille_tumeur Ganglions_touches Metastases Grade
# 1          NA 1               NA      NA                2          3
# 2    51.24100 2         16.87462       1                1          1
# 3          NA 2               NA      NA                1          NA
# 4          NA 1         25.60859      NA                NA         2
# 5    55.25488 2         43.43875       2                1          3
# 6    46.29896 1         10.60118       2                1          2
# 7    45.55468 NA              NA       0                1          2
# 8          NA NA              NA      17                NA         2
# 9    65.12404 2               NA      NA                1          NA
# 10   56.97275 2         30.60676       0                NA         NA
# 11   50.36611 2         28.05453       1                NA         NA
# 12   35.19176 1         20.88721       2                1          3
# ...
